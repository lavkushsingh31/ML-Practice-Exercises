# %% [markdown]
# # OpenCV Library Basics

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
#      ---------------------------------------- 38.1/38.1 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in c:\users\luvkush\anaconda3\envs\ml_env\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.1.78

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Datasets/calf_1.jpg")
print(img)
# Out:
# [[[58 89 90]
#   [58 89 90]
#   [57 91 91]
#   ...
#   [38 60 65]
#   [38 60 65]
#   [38 60 65]]
#
#  [[58 89 90]
#   [58 89 90]
#   [57 91 91]
#   ...
#   [38 60 65]
#   [38 60 65]
#   [38 60 65]]
#
#  [[57 88 89]
#   [58 89 90]
#   [59 90 91]
#   ...
#   [39 61 66]
#   [38 60 65]
#   [38 60 65]]
#
#  ...
#
#  [[59 66 75]
#   [58 65 74]
#   [57 63 74]
#   ...
#   [57 69 79]
#   [56 68 78]
#   [55 67 77]]
#
#  [[60 67 76]
#   [59 66 75]
#   [57 63 74]
#   ...
#   [53 65 75]
#   [53 65 75]
#   [52 64 74]]
#
#  [[60 67 76]
#   [59 66 75]
#   [58 64 75]
#   ...
#   [53 63 73]
#   [53 63 73]
#   [53 63 73]]]

# %%
img.shape
# Out:
# (959, 1280, 3)

# %%
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)
plt.show()

# %%
# since opencv reads the image and BGR instead of RBG, we need to fix the order of the array channels

image_v2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_v2)
plt.axis('off')
plt.show()
